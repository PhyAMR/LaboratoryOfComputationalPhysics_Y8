# %% [markdown]
# 1. The MickeyMouse problem
#
# a) Write a program that prints the numbers from 1 to 100. But for multiples of 3 print `Mickey` instead of the corresponding number and for the multiples of 5 print `Mouse`. For numbers which are multiples of both three and five print `MickeyMouse`
#
# b) Put the result in a tuple and substitute `Mickey` with `Donald` and `Mouse` with `Duck`

# %%
def MickeyMouse(i):
  
    if i%3 == 0 and i%5==0:
      return "MickeyMouse"
    elif i%3==0:
      return "Mickey"
    elif i%5==0:
      return "Mouse"
    else:
      return i


#for i in range(1,101):
  #print(MickeyMouse(i))

# b This part can not be done since tuples are immutable, the only way to do this is to create a list, 
# change it and convert it back to tuple. At that point I would rather just copy the function and change the returns.

dd_temp = tuple([MickeyMouse(i) for i in range(1,101)])
dd= [i for i in range(len(dd_temp))]
for n, item in enumerate(dd_temp):
  if item == "MickeyMouse":
    dd[n] = "DonaldDuck"
  if item == "Mickey":
    dd[n]="Donald"
    #print(dd)
  elif item == "Mouse":
    dd[n] = "Duck"
  else:
    dd[n]= item 

print(tuple(dd))
# Out:
# (1, 2, 'Donald', 4, 'Duck', 'Donald', 7, 8, 'Donald', 'Duck', 11, 'Donald', 13, 14, 'MickeyMouse', 16, 17, 'Donald', 19, 'Duck', 'Donald', 22, 23, 'Donald', 'Duck', 26, 'Donald', 28, 29, 'MickeyMouse', 31, 32, 'Donald', 34, 'Duck', 'Donald', 37, 38, 'Donald', 'Duck', 41, 'Donald', 43, 44, 'MickeyMouse', 46, 47, 'Donald', 49, 'Duck', 'Donald', 52, 53, 'Donald', 'Duck', 56, 'Donald', 58, 59, 'MickeyMouse', 61, 62, 'Donald', 64, 'Duck', 'Donald', 67, 68, 'Donald', 'Duck', 71, 'Donald', 73, 74, 'MickeyMouse', 76, 77, 'Donald', 79, 'Duck', 'Donald', 82, 83, 'Donald', 'Duck', 86, 'Donald', 88, 89, 'MickeyMouse', 91, 92, 'Donald', 94, 'Duck', 'Donald', 97, 98, 'Donald', 'Duck')

# %% [markdown]
# 2\. The swap function
#
# Write a function that swap the values of two input variables x and y (whatever the type). Try to do that also without a temporary variable

# %%
def swap(x,y):
    print(f"The location of x={x} is {id(x)}")
    print(f"The location of y={y} is {id(y)}")
    x,y=y,x
    print(f"The location of x={x} is {id(x)}")
    print(f"The location of y={y} is {id(y)}")
swap("h",2)

# %% [markdown]
# 3\. Computing the distance
#
# Write a function that calculates and returns the euclidean distance between two points *u* and *v*, where *u* and *v* are both 2-tuples *(x,y)*. For example, if *u=(3,0)* and *v=(0,4)*, the function should return 5

# %%
def eu_dist(u,v):
    return ((v[0]-u[0])**2+(v[1]-u[1])**2)**(1/2)
print(eu_dist((3,0),(0,4)))

# %% [markdown]
# 4\. Counting letters
#
# Write a program to calculate the number of times each character occurs in a given string *s*. Ignore differneces in capitalization

# %%
s="Write a program that prints the numbers from 1 to 100. \
But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. \
For numbers which are multiples of both three and five print MickeyMouse"

def counter(s):
    dic={}
    for i in s:
        dic[i] = 1
    for i in s:
        if i in dic.keys():
            x = dic[i]
            x+=1
            dic[i]=x
    return dic
print(counter(s))

# %% [markdown]
# 5\. Isolating the unique
#
# Write a function that determines and count the unique numbers in the list *l*

# %%
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]

def s(l):
    print(f"The unique numbers are: \n {set(l)} \n Where there are {len(set(l))} unique numbers of which {len(l)-len(set(l))} where repeated")

s(l)

# %% [markdown]
# 6\. Combination of functions
#
# Write two functions - one that returns the square of a number, and one that returns the cube. Now write a third function that returns the number raised to the 6th power using the two previous functions.

# %%
def sq(x):
    return x**2
def cub(x):
    return x**3
def sixth(x):
    return sq(cub(x))
print(sixth(2)==2**6)

# %% [markdown]
# 7\. Cubes
#
# Create a list of the cubes of x for x in *[0, 10]* using:
#
# a) a for loop
#
# b) a list comprehension

# %%
a = []
for x in range(0,11):
    a.append(x**3)
print(a)

b = [x**3 for x in range(0,11)]
print(b)

# %% [markdown]
# 8\. Nested list comprehension
#
# A Pythagorean triple is an integer solution to the Pythagorean theorem $a^2+b^2=c^2$. The first Pythagorean triple is (3,4,5). Find and put in a tuple all unique Pythagorean triples for the positive integers a, b and c less than 100.

# %%
x = [(a,b,c) for a in range(1,100) for b in range(1,100) for c in range(1,100) if a**2+b**2==(c**2)] 
print(x)

# %% [markdown]
# 9\. Normalization
#
# Write a function that takes a tuple of numbers and returns it with the entries normalized to one

# %%
def norm(u):
  return u/max(u)
print(norm([50,5]))
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[19], line 3
#
#       1 def norm(u):
#
#       2   return u/max(u)
#
# ----> 3 print(norm([50,5]))
#
#
#
# Cell In[19], line 2, in norm(u)
#
#       1 def norm(u):
#
# ----> 2   return u/max(u)
#
#
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'
